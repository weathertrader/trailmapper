# %%
import os
import numpy as np
import pandas as pd
#os.getcwd()
import folium
from folium import plugins
import geopandas
import geojson
import matplotlib.cm as cm
import webbrowser
import glob

# %%
data_input_gpx = 'data_input_gpx' 
data_processed_gpx = 'data_processed_gpx' 
data_geojson = 'data_geojson'

dir_work = '/home/craigmatthewsmith/gps_tracks'
os.chdir(dir_work)
#os.getcwd()

#os.path.isfile(gpx_file_temp)
#use_SI = True

# %%
# functions
def rgb2hex(c):
    hexc = '#%02x%02x%02x'%(int(c[0]*255), int(c[1]*255), int(c[2]*255))
    return(hexc)

# %%
geojson_file_list = glob.glob(os.path.join(data_geojson, '*.geojson'))
n_files = len(geojson_file_list)
print(n_files)                              
#print('found %s files' %(n_files))                              
#geojson_file = os.path.join(data_geojson, '2020-03-22_15-06.geojson')
#os.path.isfile(geojson_file)
# Out:
# 406

# %%
# create new GeoJson objects to reduce GeoJSON data sent to Folium map as layer
f_track = lambda x: {'color': '#FC4C02', 'weight': 5} # show some color...

# %%
# set up Folium map
#fmap = folium.Map(tiles = None, prefer_canvas=True, disable_3d=True)

#fmap = folium.Map(tiles='Stamen Terrain', prefer_canvas=True, disable_3d=True)
fmap = folium.Map(tiles='Stamen Terrain', location=[37.862606, -121.978372], zoom_start=10) 
folium.TileLayer(tiles = 'OpenStreetMap', name='OpenStreetMap', show=False).add_to(fmap)
folium.TileLayer(tiles = 'Stamen Terrain', name='Terrain Map', show=True).add_to(fmap)
cmap = cm.get_cmap('jet') # matplotlib colormap

# %%
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
features_tracks = []
features_elevation = []
features_speed = []
f = 0
#for f in range(0, 3, 1):
for f in range(0, n_files, 1):
    geojson_file = geojson_file_list[f]
    print('  processing f %s of %s ' %(f, n_files))
    
    # read geojson file
    with open(geojson_file, 'r') as file:
        geojson_data = geojson.load(file)

    #geojson_data

    for feature in geojson_data['features']:
        line = geojson.LineString(feature['geometry']['coordinates'])
        features_tracks.append(geojson.Feature(geometry=line))

    cmin_elevation = min(feature['properties']['elevation'] for feature in geojson_data['features'])
    cmax_elevation = max(feature['properties']['elevation'] for feature in geojson_data['features'])
    f_elevation = lambda x: {'color': rgb2hex(cmap((x['properties']['elevation']-cmin_elevation)/(cmax_elevation-cmin_elevation))), 'weight': 5} # cmap needs normalized data
    t_elevation = folium.features.GeoJsonTooltip(fields=['elevation'], aliases=['Elevation (m)'])

    for feature in geojson_data['features']:
        line = geojson.LineString(feature['geometry']['coordinates'])
        elevation = feature['properties']['elevation']
        features_elevation.append(geojson.Feature(geometry=line, properties={'elevation': elevation}))

    cmin_speed = min(feature['properties']['speed'] for feature in geojson_data['features'])
    cmax_speed = max(feature['properties']['speed'] for feature in geojson_data['features'])
    f_speed = lambda x: {'color': rgb2hex(cmap((x['properties']['speed']-cmin_speed)/(cmax_speed-cmin_speed))), 'weight': 5} # cmap needs normalized data
    t_speed = folium.features.GeoJsonTooltip(fields=['speed'], aliases=['Speed '])

    for feature in geojson_data['features']:
        line = geojson.LineString(feature['geometry']['coordinates'])
        speed = feature['properties']['speed']
        features_speed.append(geojson.Feature(geometry=line, properties={'speed': speed}))
# Out:
# processing f 0 of 406
# processing f 1 of 406
# processing f 2 of 406
# processing f 3 of 406
# processing f 4 of 406
# processing f 5 of 406
# processing f 6 of 406
# processing f 7 of 406
# processing f 8 of 406
# processing f 9 of 406
# processing f 10 of 406
# processing f 11 of 406
# processing f 12 of 406
# processing f 13 of 406
# processing f 14 of 406
# processing f 15 of 406
# processing f 16 of 406
# processing f 17 of 406
# processing f 18 of 406
# processing f 19 of 406
# processing f 20 of 406
# processing f 21 of 406
# processing f 22 of 406
# processing f 23 of 406
# processing f 24 of 406
# processing f 25 of 406
# processing f 26 of 406
# processing f 27 of 406
# processing f 28 of 406
# processing f 29 of 406
# processing f 30 of 406
# processing f 31 of 406
# processing f 32 of 406
# processing f 33 of 406
# processing f 34 of 406
# processing f 35 of 406
# processing f 36 of 406
# processing f 37 of 406
# processing f 38 of 406
# processing f 39 of 406
# processing f 40 of 406
# processing f 41 of 406
# processing f 42 of 406
# processing f 43 of 406
# processing f 44 of 406
# processing f 45 of 406
# processing f 46 of 406
# processing f 47 of 406
# processing f 48 of 406
# processing f 49 of 406
# processing f 50 of 406
# processing f 51 of 406
# processing f 52 of 406
# processing f 53 of 406
# processing f 54 of 406
# processing f 55 of 406
# processing f 56 of 406
# processing f 57 of 406
# processing f 58 of 406
# processing f 59 of 406
# processing f 60 of 406
# processing f 61 of 406
# processing f 62 of 406
# processing f 63 of 406
# processing f 64 of 406
# processing f 65 of 406
# processing f 66 of 406
# processing f 67 of 406
# processing f 68 of 406
# processing f 69 of 406
# processing f 70 of 406
# processing f 71 of 406
# processing f 72 of 406
# processing f 73 of 406
# processing f 74 of 406
# processing f 75 of 406
# processing f 76 of 406
# processing f 77 of 406
# processing f 78 of 406
# processing f 79 of 406
# processing f 80 of 406
# processing f 81 of 406
# processing f 82 of 406
# processing f 83 of 406
# processing f 84 of 406
# processing f 85 of 406
# processing f 86 of 406
# processing f 87 of 406
# processing f 88 of 406
# processing f 89 of 406
# processing f 90 of 406
# processing f 91 of 406
# processing f 92 of 406
# processing f 93 of 406
# processing f 94 of 406
# processing f 95 of 406
# processing f 96 of 406
# processing f 97 of 406
# processing f 98 of 406
# processing f 99 of 406
# processing f 100 of 406
# processing f 101 of 406
# processing f 102 of 406
# processing f 103 of 406
# processing f 104 of 406
# processing f 105 of 406
# processing f 106 of 406
# processing f 107 of 406
# processing f 108 of 406
# processing f 109 of 406
# processing f 110 of 406
# processing f 111 of 406
# processing f 112 of 406
# processing f 113 of 406
# processing f 114 of 406
# processing f 115 of 406
# processing f 116 of 406
# processing f 117 of 406
# processing f 118 of 406
# processing f 119 of 406
# processing f 120 of 406
# processing f 121 of 406
# processing f 122 of 406
# processing f 123 of 406
# processing f 124 of 406
# processing f 125 of 406
# processing f 126 of 406
# processing f 127 of 406
# processing f 128 of 406
# processing f 129 of 406
# processing f 130 of 406
# processing f 131 of 406
# processing f 132 of 406
# processing f 133 of 406
# processing f 134 of 406
# processing f 135 of 406
# processing f 136 of 406
# processing f 137 of 406
# processing f 138 of 406
# processing f 139 of 406
# processing f 140 of 406
# processing f 141 of 406
# processing f 142 of 406
# processing f 143 of 406
# processing f 144 of 406
# processing f 145 of 406
# processing f 146 of 406
# processing f 147 of 406
# processing f 148 of 406
# processing f 149 of 406
# processing f 150 of 406
# processing f 151 of 406
# processing f 152 of 406
# processing f 153 of 406
# processing f 154 of 406
# processing f 155 of 406
# processing f 156 of 406
# processing f 157 of 406
# processing f 158 of 406
# processing f 159 of 406
# processing f 160 of 406
# processing f 161 of 406
# processing f 162 of 406
# processing f 163 of 406
# processing f 164 of 406
# processing f 165 of 406
# processing f 166 of 406
# processing f 167 of 406
# processing f 168 of 406
# processing f 169 of 406
# processing f 170 of 406
# processing f 171 of 406
# processing f 172 of 406
# processing f 173 of 406
# processing f 174 of 406
# processing f 175 of 406
# processing f 176 of 406
# processing f 177 of 406
# processing f 178 of 406
# processing f 179 of 406
# processing f 180 of 406
# processing f 181 of 406
# processing f 182 of 406
# processing f 183 of 406
# processing f 184 of 406
# processing f 185 of 406
# processing f 186 of 406
# processing f 187 of 406
# processing f 188 of 406
# processing f 189 of 406
# processing f 190 of 406
# processing f 191 of 406
# processing f 192 of 406
# processing f 193 of 406
# processing f 194 of 406
# processing f 195 of 406
# processing f 196 of 406
# processing f 197 of 406
# processing f 198 of 406
# processing f 199 of 406
# processing f 200 of 406
# processing f 201 of 406
# processing f 202 of 406
# processing f 203 of 406
# processing f 204 of 406
# processing f 205 of 406
# processing f 206 of 406
# processing f 207 of 406
# processing f 208 of 406
# processing f 209 of 406
# processing f 210 of 406
# processing f 211 of 406
# processing f 212 of 406
# processing f 213 of 406
# processing f 214 of 406
# processing f 215 of 406
# processing f 216 of 406
# processing f 217 of 406
# processing f 218 of 406
# processing f 219 of 406
# processing f 220 of 406
# processing f 221 of 406
# processing f 222 of 406
# processing f 223 of 406
# processing f 224 of 406
# processing f 225 of 406
# processing f 226 of 406
# processing f 227 of 406
# processing f 228 of 406
# processing f 229 of 406
# processing f 230 of 406
# processing f 231 of 406
# processing f 232 of 406
# processing f 233 of 406
# processing f 234 of 406
# processing f 235 of 406
# processing f 236 of 406
# processing f 237 of 406
# processing f 238 of 406
# processing f 239 of 406
# processing f 240 of 406
# processing f 241 of 406
# processing f 242 of 406
# processing f 243 of 406
# processing f 244 of 406
# processing f 245 of 406
# processing f 246 of 406
# processing f 247 of 406
# processing f 248 of 406
# processing f 249 of 406
# processing f 250 of 406
# processing f 251 of 406
# processing f 252 of 406
# processing f 253 of 406
# processing f 254 of 406
# processing f 255 of 406
# processing f 256 of 406
# processing f 257 of 406
# processing f 258 of 406
# processing f 259 of 406
# processing f 260 of 406
# processing f 261 of 406
# processing f 262 of 406
# processing f 263 of 406
# processing f 264 of 406
# processing f 265 of 406
# processing f 266 of 406
# processing f 267 of 406
# processing f 268 of 406
# processing f 269 of 406
# processing f 270 of 406
# processing f 271 of 406
# processing f 272 of 406
# processing f 273 of 406
# processing f 274 of 406
# processing f 275 of 406
# processing f 276 of 406
# processing f 277 of 406
# processing f 278 of 406
# processing f 279 of 406
# processing f 280 of 406
# processing f 281 of 406
# processing f 282 of 406
# processing f 283 of 406
# processing f 284 of 406
# processing f 285 of 406
# processing f 286 of 406
# processing f 287 of 406
# processing f 288 of 406
# processing f 289 of 406
# processing f 290 of 406
# processing f 291 of 406
# processing f 292 of 406
# processing f 293 of 406
# processing f 294 of 406
# processing f 295 of 406
# processing f 296 of 406
# processing f 297 of 406
# processing f 298 of 406
# processing f 299 of 406
# processing f 300 of 406
# processing f 301 of 406
# processing f 302 of 406
# processing f 303 of 406
# processing f 304 of 406
# processing f 305 of 406
# processing f 306 of 406
# processing f 307 of 406
# processing f 308 of 406
# processing f 309 of 406
# processing f 310 of 406
# processing f 311 of 406
# processing f 312 of 406
# processing f 313 of 406
# processing f 314 of 406
# processing f 315 of 406
# processing f 316 of 406
# processing f 317 of 406
# processing f 318 of 406
# processing f 319 of 406
# processing f 320 of 406
# processing f 321 of 406
# processing f 322 of 406
# processing f 323 of 406
# processing f 324 of 406
# processing f 325 of 406
# processing f 326 of 406
# processing f 327 of 406
# processing f 328 of 406
# processing f 329 of 406
# processing f 330 of 406
# processing f 331 of 406
# processing f 332 of 406
# processing f 333 of 406
# processing f 334 of 406
# processing f 335 of 406
# processing f 336 of 406
# processing f 337 of 406
# processing f 338 of 406
# processing f 339 of 406
# processing f 340 of 406
# processing f 341 of 406
# processing f 342 of 406
# processing f 343 of 406
# processing f 344 of 406
# processing f 345 of 406
# processing f 346 of 406
# processing f 347 of 406
# processing f 348 of 406
# processing f 349 of 406
# processing f 350 of 406
# processing f 351 of 406
# processing f 352 of 406
# processing f 353 of 406
# processing f 354 of 406
# processing f 355 of 406
# processing f 356 of 406
# processing f 357 of 406
# processing f 358 of 406
# processing f 359 of 406
# processing f 360 of 406
# processing f 361 of 406
# processing f 362 of 406
# processing f 363 of 406
# processing f 364 of 406
# processing f 365 of 406
# processing f 366 of 406
# processing f 367 of 406
# processing f 368 of 406
# processing f 369 of 406
# processing f 370 of 406
# processing f 371 of 406
# processing f 372 of 406
# processing f 373 of 406
# processing f 374 of 406
# processing f 375 of 406
# processing f 376 of 406
# processing f 377 of 406
# processing f 378 of 406
# processing f 379 of 406
# processing f 380 of 406
# processing f 381 of 406
# processing f 382 of 406
# processing f 383 of 406
# processing f 384 of 406
# processing f 385 of 406
# processing f 386 of 406
# processing f 387 of 406
# processing f 388 of 406
# processing f 389 of 406
# processing f 390 of 406
# processing f 391 of 406
# processing f 392 of 406
# processing f 393 of 406
# processing f 394 of 406
# processing f 395 of 406
# processing f 396 of 406
# processing f 397 of 406
# processing f 398 of 406
# processing f 399 of 406
# processing f 400 of 406
# processing f 401 of 406
# processing f 402 of 406
# processing f 403 of 406
# processing f 404 of 406
# processing f 405 of 406

# %%
print('appending features to map ')

geojson_data_elevation = geojson.FeatureCollection(features_elevation)
folium.GeoJson(geojson_data_elevation, style_function=f_elevation, tooltip=t_elevation, name='Elevation (m)', show=False, smooth_factor=3.0).add_to(fmap)
        
geojson_data_speed = geojson.FeatureCollection(features_speed)
folium.GeoJson(geojson_data_speed, style_function=f_speed, tooltip=t_speed, name='Speed ', show=False, smooth_factor=3.0).add_to(fmap)

geojson_data_track = geojson.FeatureCollection(features_tracks)
folium.GeoJson(geojson_data_track, style_function=f_track, name='Track only', show=True, smooth_factor=3.0).add_to(fmap)

fmap

# %%
# add layer control widget
folium.LayerControl(collapsed=False).add_to(fmap)

# save map to html file
fmap.fit_bounds(fmap.get_bounds())

html_file = os.path.join(dir_work, 'index.html')
if os.path.isfile(html_file):
    os.system('rm -f '+html_file)
fmap.save(html_file)
# open html file in default browser
webbrowser.open(html_file, new=2, autoraise=True)
